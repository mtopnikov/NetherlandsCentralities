# %% [markdown]
# # Vizualize for illustrations

# %% [markdown]
# Create some illustrative non-analytical plots for the bachalors project

# %% [markdown]
# ## Zipf's law for the Netherlands ans for UK as opposites

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm

# %%
medium_font = fm.FontProperties(fname =  r"D:/bachelors/datasets/viz/Roboto-Medium.ttf",size = 12)
regluar_font = fm.FontProperties(fname = r"D:\bachelors\datasets\viz\Roboto-Regular.ttf", size = 12)

colors = {
    'peach' : '#FCB886',
    'blue' : '#6FC7F7',
    'green' : '#78AF34',
    'red' : '#D25B5B',
    'grey' : '#8B8B8B'
}

# %%
import requests 
from bs4 import BeautifulSoup as soup

# %%
page_soup = soup(requests.get('https://en.wikipedia.org/wiki/List_of_urban_areas_in_the_United_Kingdom').text)
table = page_soup.find('table', {'class' : 'wikitable sortable'})

# %%
uk_cities = []
for row in table.find_all('tr')[1:]:
    cells = row.find_all('td')
    name = cells[0].text.lower().replace('\n', '').replace(' built-up area', '').title()
    population = int(cells[1].text.replace(',', '').replace('\n', '').split('[')[0])
    uk_cities.append([name, population])
    
uk_cities = pd.DataFrame(uk_cities, columns = ['city', 'population'])

# %%
page_soup = soup(requests.get('https://population.mongabay.com/population/netherlands').text)
table = page_soup.find('table', {'content' : 'List of the biggest cities in Netherlands'})

# %%
netherlands_table = []
for row in table.find_all('tr')[1:]:
    name = row.find('span', {'itemprop' : 'name'}).text
    population = int(row.find('td', {'class' : 'r'}).text.strip().replace(',', ''))
    netherlands_table.append([name, population])
    
netherlands_table = pd.DataFrame(netherlands_table, columns = ['city', 'population'])

# %%
uk_cities.iloc[0, -1]
# Out:
# 9787426

# %%
def modify(df):
    df['rank'] = [i for i in range(1, len(df) + 1)]
    df['norm_pop'] = df['population'] / df.population.max()
    return(df)

uk_cities = modify(uk_cities)
netherlands_table = modify(netherlands_table)

# %%
plt.figure(figsize = (7,7), dpi = 192)
netherlands_table[:75].norm_pop.plot(label = 'Нидерланды', color = colors['peach'])
uk_cities.norm_pop.plot(label = 'Великобритания', color = colors['blue'])
plt.plot([1/i for i in range(1, 76)], label = 'Идеальное распределение', color = colors['green'])
plt.yscale('log')
plt.xticks([i for i in range(0, 76, 5)], [i for i in range(0, 76, 5)], fontproperties = regluar_font, fontsize = 12)
plt.yticks(fontproperties = regluar_font, fontsize = 12)

plt.xlabel('Ранг', fontproperties = medium_font, fontsize = 12)
plt.ylabel('Численность населения, доля от максимума', fontproperties = medium_font, fontsize = 12)
plt.ylim(top = 1)
plt.grid()
# plt.title('Нидерланды', fontproperties = medium_font, fontsize = 16)

plt.legend(prop = regluar_font, frameon = False, bbox_to_anchor = (1.1,-0.075), ncol = 3)
plt.tight_layout()
plt.savefig('D:/bachelors/illustrations/01_ranksize_distribution_2.png')
# plt.legend()

# %%
import googletrans
import geocoder
from time import sleep
from tqdm import tqdm

# %%
netherlands_table['lat'], netherlands_table['lon'] = pd.Series(), pd.Series()

# %%
def gcode(location):
    """
    Sends request to geocoding server, returns tuple with coordinates
    """
    try:
        g = geocoder.arcgis(location).json
        return g['lat'], g['lng'], g
    except Exception as e:
        print(e)
        return None, None, g

# %%
netherlands_table['address'] = netherlands_table.city + ', Netherlands'

# %%
responses = []
for i, row in tqdm(netherlands_table.iterrows()):
    location = row['address']
    lat, lon, response = gcode(location)
    sleep(1)
    
    responses.append([location, response])
    
    netherlands_table.loc[netherlands_table.address == location, 'lat'] = lat
    netherlands_table.loc[netherlands_table.address == location, 'lon'] = lon
# Out:
# 270it [07:05,  1.57s/it]Status code Unknown from https://geocode.arcgis.com/arcgis/rest/services/World/GeocodeServer/find: ERROR - HTTPSConnectionPool(host='geocode.arcgis.com', port=443): Read timed out. (read timeout=5.0)
# 'NoneType' object is not subscriptable
# 1402it [36:54,  1.56s/it]

# %%
netherlands_table.to_csv('D:/bachelors/illustrations/map_cities.csv', index = None)

# %%
plt.figure(dpi = 192)
netherlands_table[4:14].plot.bar(x = 'city', y = 'population', color = colors['blue'], legend = False)
plt.yticks([i for i in range(0,260000, 50000)], [i for i in range(0,260, 50)], fontproperties = regluar_font)
plt.xticks([i for i in netherlands_table[4:14].city], netherlands_table[4:14], fontproperties = medium_fontfont)
plt.xlabel('')
plt.ylabel('Население, тыс. чел.', fontproperties = medium_font)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-cff0464ce898> in <module>
#       2 netherlands_table[4:14].plot.bar(x = 'city', y = 'population', color = colors['blue'], legend = False)
#       3 plt.yticks([i for i in range(0,260000, 50000)], [i for i in range(0,260, 50)], fontproperties = regluar_font)
# ----> 4 plt.xticks([i for i in netherlands_table[4:14].city], netherlands_table[4:14], fontproperties = medium_fontfont)
#       5 plt.xlabel('')
#       6 plt.ylabel('Население, тыс. чел.', fontproperties = medium_font)
#
# NameError: name 'medium_fontfont' is not defined

# %%
len(netherlands_table[4:][netherlands_table[4:]['population'] >= 150000])
# Out:
# 7

# %% [markdown]
# # Survey params

# %%
df = pd.DataFrame({
    'year' : [i for i in range(2010,2018)],
    'sample' : [78009, 74590, 75041, 80529, 87614, 66987, 64335, 68764],
    'resp_sample_share' : [56.6, 56.8, 57.7, 52.6, 48.6, 55.8, 59.3, 53.8],
    'resp_pop_share' : [.27] + [.26] * 4 + [.22, .23, .22]
}).set_index('year')

# %%
df
# Out:
#       sample  resp_sample_share  resp_pop_share
# year
# 2010   78009               56.6            0.27
# 2011   74590               56.8            0.26
# 2012   75041               57.7            0.26
# 2013   80529               52.6            0.26
# 2014   87614               48.6            0.26
# 2015   66987               55.8            0.22
# 2016   64335               59.3            0.23
# 2017   68764               53.8            0.22

# %%
fig = plt.figure(figsize = (7,7), dpi = 192)
df['sample'].plot.bar(color = colors['blue'])
plt.plot(df['resp_pop_share'])
plt.xticks(rotation = 0, fontproperties = regluar_font)
plt.xlabel('Год проведения', fontproperties = medium_font)

plt.yticks(fontproperties = regluar_font)
plt.ylabel('Число опрошенных', fontproperties = medium_font)

plt.grid(axis = 'y')

# %% [markdown]
# # Correspondence

# %%
df = pd.read_csv('translated_data_v2/data_2017.csv')
# Out:
# C:\Users\mtopn\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,10,13,16,17,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import json

# %%
with open('Variables/mappers/communes_raw_to_2018_Terra.json') as infile:
    communes = json.load(infile)

# %%
communes
# Out:
# {'Hellevoetsluis': 'Hellevoetsluis',
#  'Geldermalsen': 'Geldermalsen',
#  'Meierijstad': 'Meierijstad',
#  'Grootegast': 'Grootegast',
#  'Haarlem': 'Haarlem',
#  'Purmerend': 'Purmerend',
#  'Niedorp': 'Hollands Kroon',
#  'Ameland': 'Ameland',
#  'Dronten': 'Dronten',
#  'Loon op Za': 'Loon op Zand',
#  'Midden-Drenthe': 'Midden-Drenthe',
#  'Bergh': 'Montferland',
#  'Wieringerm': 'Hollands Kroon',
#  'Haarlemmermeer': 'Haarlemmermeer',
#  'Amerongen': 'Utrechtse Heuvelrug',
#  'Sint-Oedenrode': 'Meierijstad',
#  'Maarn': 'Utrechtse Heuvelrug',
#  'Reusel-De Mierden': 'Reusel-De Mierden',
#  'Schouwen-D': 'Schouwen-Duiveland',
#  'Neerijnen': 'Neerijnen',
#  'Meerlo-Wanssum': 'Horst aan de Maas',
#  'Menaldumad': 'Waadhoeke',
#  'Wijk bij D': 'Wijk bij Duurstede',
#  'Menterwolde': 'Midden-Groningen',
#  'Heerhugowaard': 'Heerhugowaard',
#  'Haren': 'Haren',
#  'Steenbergen': 'Steenbergen',
#  'Heerde': 'Heerde',
#  'Zeist': 'Zeist',
#  'Amsterdam': 'Amsterdam',
# ...

# %%
df['geo_arrival'] = df['geo_arrival'].map(communes)
df['geo_departure'] = df['geo_departure'].map(communes)

# %%
df['geo_arrival']
# Out:
# 0              Marum
# 1               Leek
# 2                NaN
# 3          Groningen
# 4           Ten Boer
#              ...
# 115156      Lelystad
# 115157    Wijdemeren
# 115158    Wijdemeren
# 115159    Wijdemeren
# 115160           NaN
# Name: geo_arrival, Length: 115161, dtype: object

# %%
with open("Variables/mappers/communes_names_toRussian_map.json") as infile:
    communes_rus = json.load(infile)

# %%
df['geo_arrival'] = df['geo_arrival'].map(communes_rus)
df['geo_departure'] = df['geo_departure'].map(communes_rus)

# %%
pdf = pd.pivot_table(df, 'uid_person', 'geo_departure', 'geo_arrival', 'nunique')

# %%
pdf.loc[['Амстердам', 'Роттердам', 'Утрехт', 'Гаага', 'Тилбург', 'Гронинген'],
        ['Амстердам', 'Роттердам', 'Утрехт', 'Гаага', 'Тилбург', 'Гронинген']].to_excel('D:/bachelors/illustrations/sample_corresp.xlsx')

# %% [markdown]
# # Datatable Sample

# %%
import pandas as pd

# %%
df = pd.read_spss('D:/bachelors/datasets/MobNed_dat/Databestand MON 2009.sav').head()

# %%
df.iloc[:, :10]
# Out:
#    Jaar     Maand                   Dag          huishoud         persoon  \
# 0  2009   Januari  26e dag van de maand  Nieuw huishouden  Nieuwe persoon
# 1  2009   Januari  26e dag van de maand               Nvt             Nvt
# 2  2009   Januari  26e dag van de maand  Nieuw huishouden  Nieuwe persoon
# 3  2009   Januari  26e dag van de maand               Nvt             Nvt
# 4  2008  December   8e dag van de maand  Nieuw huishouden  Nieuwe persoon
#
#                  verpl         rit       hhid       persid       verplid
# 0  Nieuwe verplaatsing  Nieuwe rit  8116130.0  811613001.0  8.116130e+10
# 1  Nieuwe verplaatsing  Nieuwe rit  8116130.0  811613001.0  8.116130e+10
# 2  Nieuwe verplaatsing  Nieuwe rit  8117129.0  811712901.0  8.117129e+10
# 3  Nieuwe verplaatsing  Nieuwe rit  8117129.0  811712901.0  8.117129e+10
# 4  Nieuwe verplaatsing  Nieuwe rit  8120101.0  812010101.0  8.120101e+10

# %%
df_2 = pd.read_csv('D:/bachelors/datasets/translated_data_v2/data_2009.csv')

# %%
df_2.head()
# Out:
#      geo_arrival  dem_age  hh_n_6_11  hh_n_12_17  hh_owns_bike  hh_owns_moped  \
# 0  Sonen Breugel       79        0.0         0.0             1              0
# 1      Eindhoven       79        0.0         0.0             1              0
# 2           Tiel       80        0.0         0.0             0              0
# 3           Tiel       80        0.0         0.0             0              0
# 4      Rotterdam       62        0.0         0.0             1              0
#
#    n_mopeds  hh_n_over18      geo_province      car_age  ...  dem_sex  \
# 0         0          1.0  Северный Брабант         2006  ...  Мужской
# 1         0          1.0  Северный Брабант         2006  ...  Мужской
# 2         0          2.0        Гелдерланд  старше 1996  ...  Женский
# 3         0          2.0        Гелдерланд  старше 1996  ...  Женский
# 4         0          2.0   Южная Голландия  1997 - 1999  ...  Мужской
#
# ...

# %% [markdown]
# # Municipatities Merge

# %%
import os

# %%
os.chdir('D:/bachelors/datasets/')

# %%
shapes = [i for i in os.listdir('GeementenShapes/') if '.shp' in i]

# %%
shapes[0].split('.')[0].split('_')[1]
# Out:
# '1995'

# %%
import geopandas as gpd

# %%
years = []
n_communes = []
for shape in shapes:
    years.append(shape.split('.')[0].split('_')[1])
    
    n_communes.append(len(
        gpd.read_file(f'GeementenShapes/{shape}')
    ))

# %%
plt.figure(figsize=(14,7), facecolor = 'w')
plt.plot(n_communes, color = 'k')
plt.fill_between([i for i in range(len(n_communes))], n_communes, color = colors['grey'])
plt.xticks([i for i in range(len(n_communes))], years, fontproperties = regluar_font)
plt.yticks(fontproperties = regluar_font)
plt.ylim(0,700)
plt.xlim(0, len(n_communes)-1)
plt.grid()
plt.xlabel('Год', fontproperties = medium_font)
plt.ylabel('Число муниципалитетов', fontproperties = medium_font)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sample

# %%
df = pd.read_excel('D:/bachelors/illustrations/sample_corresp.xlsx', sheet_name = 'Sheet2').set_index('jaar')

# %%
pd.to_numeric(df['Absoluut']).plot(kind = 'barh', color = colors['grey'], figsize = (14,7))
plt.xticks([i for i in range(0, 80000, 10000)], [i for i in range(0,80, 10)],fontproperties = regluar_font)
plt.yticks(fontproperties = regluar_font)
plt.xlabel('Число респондентов, тыс.',fontproperties = medium_font)
plt.ylabel('Год проведения', fontproperties = medium_font)

plt.grid(axis = 'x')

# %%
df['Absoluut'].str.strip()
# Out:
# jaar
# 2004    29221
# 2005      NaN
# 2006    23695
# 2007      NaN
# 2010      NaN
# 2011      NaN
# 2012      NaN
# 2013      NaN
# 2014      NaN
# 2015      NaN
# 2016      NaN
# 2017      NaN
# Name: Absoluut, dtype: object

# %% [markdown]
# # Centrality mertics

# %%
import networkx as nx

# %%
G = nx.karate_club_graph()
pos = nx.spring_layout(G)

# %%
import random
#code creating G here
for (u,v,w) in G.edges(data=True):
    w['weight'] = random.randint(0,10)

# %%
def draw(G, pos, measures, measure_name):
    plt.figure(figsize = (7,7))
    nodes = nx.draw_networkx_nodes(G, pos, node_size=250, cmap=plt.cm.Greys, 
                                   node_color=list(measures.values()),
                                   edgecolors = 'k',
                                   nodelist=(measures.keys()))
#     nodes.set_norm(mcolors.SymLogNorm(linthresh=0.01, linscale=1))
    
    # labels = nx.draw_networkx_labels(G, pos)
    edges = nx.draw_networkx_edges(G, pos)

#     plt.title(measure_name)
#     plt.colorbar(nodes)
    plt.axis('off')
    plt.show()
#     plt.savefig(f'D:/bachelors/illustrations/{measure_name}.png')

# %%
draw(G, pos, nx.degree_centrality(G), measure_name = 'Degree')
# plt.savefig('D:/bachelors/illustrations/01_Degree_centrality.png')

# %%
draw(G, pos, nx.closeness_centrality(G), measure_name = 'Closeness')
# plt.savefig('D:/bachelors/illustrations/02_Closeness_centrality.png')

# %%
draw(G, pos, nx.eigenvector_centrality(G), measure_name = 'Eigenvector')
# plt.savefig('D:/bachelors/illustrations/03_Eigenvector_centrality.png')

# %%
draw(G, pos, nx.current_flow_betweenness_centrality(G, weight = 'weight'), measure_name = 'Between')
# Out:
# C:\Users\mtopn\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
